# %% [markdown]
# <a href="https://colab.research.google.com/github/vittogiangreco/tps-pii-colab/blob/main/set_Pr%C3%A1ctica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
estudiantes = [
    {'name': 'Abud Laspiur, Lourdes Mariel', 'section': 'C', 'dob': '05/12/2006'},
    {'name': 'Amador, Luana Micaela', 'section': 'C', 'dob': '09/12/2006'},
    {'name': 'Anaquin, Leonardo Ezequiel', 'section': 'C', 'dob': '06/09/2005'},
    {'name': 'Araoz Sanchez, Lautaro Nahuel', 'section': 'C', 'dob': '28/12/2005'},
    {'name': 'Argañaraz, Agostina Abril', 'section': 'C', 'dob': '11/10/2006'},
    {'name': 'Barrera, Matias Ezequiel', 'section': 'C', 'dob': '27/02/2007'},
    {'name': 'Barrera, Matias Ezequiel', 'section': 'C', 'dob': '27/02/2007'},  # Repetido
    {'name': 'Barrozo Vedia, Joaquin Nicolas', 'section': 'C', 'dob': '15/04/2006'},
    {'name': 'Bettinelli, Valentino', 'section': 'C', 'dob': '12/07/2006'},
    {'name': 'Bracamonte Martinez, Salvador', 'section': 'C', 'dob': '02/11/2005'},
    {'name': 'Colque Rivero, Ariana Zoe Del Valle', 'section': 'C', 'dob': '27/12/2006'},
    {'name': 'Diaz, Dulce Maitena', 'section': 'C', 'dob': '11/12/2006'},
    {'name': 'Figueroa, Santino Josue', 'section': 'C', 'dob': '12/05/2007'},
    {'name': 'Figueroa, Santino Josue', 'section': 'C', 'dob': '12/05/2007'},  # Repetido
    {'name': 'Flores Cardozo, Agustina Tiara', 'section': 'C', 'dob': '18/03/2006'},
    {'name': 'Gallo, Octavio Ismael', 'section': 'C', 'dob': '04/08/2006'},
    {'name': 'Galvan, Lourdes Yamila', 'section': 'C', 'dob': '19/08/2005'},
    {'name': 'Giangreco, Vitto Tomasso', 'section': 'C', 'dob': '21/03/2007'},
    {'name': 'Grancara, Martina Luna', 'section': 'C', 'dob': '15/12/2006'},
    {'name': 'Guanca, Sara Elizabeth', 'section': 'C', 'dob': '17/01/2007'},
    {'name': 'Lopez, Victoria Constanza', 'section': 'C', 'dob': '12/11/2007'},
    {'name': 'Mamani Garrido, Rosario Agostina', 'section': 'C', 'dob': '24/10/2006'},
    {'name': 'Marinaro, Martin Ezequiel', 'section': 'C', 'dob': '03/11/2006'},
    {'name': 'Merluzzi Dagum, Ignacio', 'section': 'C', 'dob': '22/12/2005'},
    {'name': 'Messina, Martina', 'section': 'C', 'dob': '13/07/2005'},
    {'name': 'Rasuk, Karim', 'section': 'C', 'dob': '13/07/2007'},
    {'name': 'Rasuk, Karim', 'section': 'C', 'dob': '13/07/2007'},  # Repetido
    {'name': 'Rios, Lucia Magali', 'section': 'C', 'dob': '22/09/2006'},
    {'name': 'Sanchez Flores, Matías Agustín', 'section': 'C', 'dob': '15/02/2007'},
    {'name': 'Scarano, Renato Marcelo', 'section': 'C', 'dob': '06/12/2006'},
    {'name': 'Sierra, Lucas Mauricio', 'section': 'C', 'dob': '03/04/2005'},
    {'name': 'Tapia, Martin Gabriel', 'section': 'C', 'dob': '30/05/2006'},
    {'name': 'Vilte, Mia Antonella Alondra', 'section': 'C', 'dob': '10/09/2005'},
    {'name': 'Virgillito, Katya Milena', 'section': 'C', 'dob': '19/06/2007'},
    {'name': 'Alurralde, Solange Stefania', 'section': 'D', 'dob': '02/04/2007'},
    {'name': 'Alvarado, Ludmila Del Milagro', 'section': 'D', 'dob': '06/09/2006'},
    {'name': 'Angel, Camila Juliana', 'section': 'D', 'dob': '07/03/2007'},
    {'name': 'Arenas, Lucas Gabriel', 'section': 'D', 'dob': '26/06/2007'},
    {'name': 'Caseres, Maria Antonia', 'section': 'D', 'dob': '01/07/2006'},
    {'name': 'Castillo, Paulina Milagros', 'section': 'D', 'dob': '01/06/2007'},
    {'name': 'Correa Segovia, Hugo Mariano', 'section': 'D', 'dob': '04/12/2006'},
    {'name': 'Correa Segovia, Hugo Mariano', 'section': 'D', 'dob': '04/12/2006'},  # Repetido
    {'name': 'D Elia, Alvaro Tadeo', 'section': 'D', 'dob': '27/08/2006'},
    {'name': 'Flores, Victoria Agustina', 'section': 'D', 'dob': '12/12/2006'},
    {'name': 'Geronimo Soriano, Lizzie Amaya', 'section': 'D', 'dob': '20/01/2007'},
    {'name': 'Guzman, Angélica Morena', 'section': 'D', 'dob': '11/04/2007'},
    {'name': 'Guzman, Jazmin Esmeralda Belen', 'section': 'D', 'dob': '31/07/2006'},
    {'name': 'Jaime, Anita Maria Belen', 'section': 'D', 'dob': '19/04/2007'},
    {'name': 'Lacour Polo, Nazarena', 'section': 'D', 'dob': '19/12/2005'},
    {'name': 'Lascano Guanca, Marcelo Fabricio', 'section': 'D', 'dob': '17/02/2006'},
    {'name': 'Lezcano, Celia Morena', 'section': 'D', 'dob': '01/07/2005'},
    {'name': 'Martinez, Tomas Andres', 'section': 'D', 'dob': '22/03/2007'},
    {'name': 'Portella Valdivia, Pedro Francisco', 'section': 'D', 'dob': '24/01/2007'},
    {'name': 'Retamal Cisneros, Zacarias Josue', 'section': 'D', 'dob': '24/02/2007'},
    {'name': 'Rosales, Francisco Gabriel', 'section': 'D', 'dob': '14/11/2006'},
    {'name': 'Salem Barba, Mahia', 'section': 'D', 'dob': '14/10/2005'},
    {'name': 'Soto Camara, Agustin Ignacio', 'section': 'D', 'dob': '07/11/2005'},
    {'name': 'Villalba, Irina', 'section': 'D', 'dob': '09/09/2006'},
    {'name': 'Voltolini, Emanuel Tobias', 'section': 'D', 'dob': '17/09/2006'},
    {'name': 'Zalazar, Santino Stefano', 'section': 'D', 'dob': '30/09/2006'},
    {'name': 'Zalazar, Santino Stefano', 'section': 'D', 'dob': '30/09/2006'}  # Repetido
]

# %%
# Spoiler de estructura que veremos en los siguientes TPs
import json
for estudiante in estudiantes:
  alumno_json = json.dumps(estudiante,indent=4,ensure_ascii=False)
  print(alumno_json,",")
# Out:
# {
#     "name": "Abud Laspiur, Lourdes Mariel",
#     "section": "C",
#     "dob": "05/12/2006"
# } ,
# {
#     "name": "Amador, Luana Micaela",
#     "section": "C",
#     "dob": "09/12/2006"
# } ,
# {
#     "name": "Anaquin, Leonardo Ezequiel",
#     "section": "C",
#     "dob": "06/09/2005"
# } ,
# {
#     "name": "Araoz Sanchez, Lautaro Nahuel",
#     "section": "C",
#     "dob": "28/12/2005"
# } ,
# {
#     "name": "Argañaraz, Agostina Abril",
#     "section": "C",
#     "dob": "11/10/2006"
# } ,
# {
#     "name": "Barrera, Matias Ezequiel",
#     "section": "C",
#     "dob": "27/02/2007"
# } ,
# {
#     "name": "Barrera, Matias Ezequiel",
#     "section": "C",
#     "dob": "27/02/2007"
# } ,
# {
#     "name": "Barrozo Vedia, Joaquin Nicolas",
#     "section": "C",
#     "dob": "15/04/2006"
# } ,
# {
#     "name": "Bettinelli, Valentino",
#     "section": "C",
#     "dob": "12/07/2006"
# } ,
# {
#     "name": "Bracamonte Martinez, Salvador",
#     "section": "C",
#     "dob": "02/11/2005"
# } ,
# {
#     "name": "Colque Rivero, Ariana Zoe Del Valle",
#     "section": "C",
#     "dob": "27/12/2006"
# } ,
# {
#     "name": "Diaz, Dulce Maitena",
#     "section": "C",
#     "dob": "11/12/2006"
# } ,
# {
#     "name": "Figueroa, Santino Josue",
#     "section": "C",
#     "dob": "12/05/2007"
# } ,
# {
#     "name": "Figueroa, Santino Josue",
#     "section": "C",
#     "dob": "12/05/2007"
# } ,
# {
#     "name": "Flores Cardozo, Agustina Tiara",
#     "section": "C",
#     "dob": "18/03/2006"
# } ,
# {
#     "name": "Gallo, Octavio Ismael",
#     "section": "C",
#     "dob": "04/08/2006"
# } ,
# {
#     "name": "Galvan, Lourdes Yamila",
#     "section": "C",
#     "dob": "19/08/2005"
# } ,
# {
#     "name": "Giangreco, Vitto Tomasso",
#     "section": "C",
#     "dob": "21/03/2007"
# } ,
# {
#     "name": "Grancara, Martina Luna",
#     "section": "C",
#     "dob": "15/12/2006"
# } ,
# {
#     "name": "Guanca, Sara Elizabeth",
#     "section": "C",
#     "dob": "17/01/2007"
# } ,
# {
#     "name": "Lopez, Victoria Constanza",
#     "section": "C",
#     "dob": "12/11/2007"
# } ,
# {
#     "name": "Mamani Garrido, Rosario Agostina",
#     "section": "C",
#     "dob": "24/10/2006"
# } ,
# {
#     "name": "Marinaro, Martin Ezequiel",
#     "section": "C",
#     "dob": "03/11/2006"
# } ,
# {
#     "name": "Merluzzi Dagum, Ignacio",
#     "section": "C",
#     "dob": "22/12/2005"
# } ,
# {
#     "name": "Messina, Martina",
#     "section": "C",
#     "dob": "13/07/2005"
# } ,
# {
#     "name": "Rasuk, Karim",
#     "section": "C",
#     "dob": "13/07/2007"
# } ,
# {
#     "name": "Rasuk, Karim",
#     "section": "C",
#     "dob": "13/07/2007"
# } ,
# {
#     "name": "Rios, Lucia Magali",
#     "section": "C",
#     "dob": "22/09/2006"
# } ,
# {
#     "name": "Sanchez Flores, Matías Agustín",
#     "section": "C",
#     "dob": "15/02/2007"
# } ,
# {
#     "name": "Scarano, Renato Marcelo",
#     "section": "C",
#     "dob": "06/12/2006"
# } ,
# {
#     "name": "Sierra, Lucas Mauricio",
#     "section": "C",
#     "dob": "03/04/2005"
# } ,
# {
#     "name": "Tapia, Martin Gabriel",
#     "section": "C",
#     "dob": "30/05/2006"
# } ,
# {
#     "name": "Vilte, Mia Antonella Alondra",
#     "section": "C",
#     "dob": "10/09/2005"
# } ,
# {
#     "name": "Virgillito, Katya Milena",
#     "section": "C",
#     "dob": "19/06/2007"
# } ,
# {
#     "name": "Alurralde, Solange Stefania",
#     "section": "D",
#     "dob": "02/04/2007"
# } ,
# {
#     "name": "Alvarado, Ludmila Del Milagro",
#     "section": "D",
#     "dob": "06/09/2006"
# } ,
# {
#     "name": "Angel, Camila Juliana",
#     "section": "D",
#     "dob": "07/03/2007"
# } ,
# {
#     "name": "Arenas, Lucas Gabriel",
#     "section": "D",
#     "dob": "26/06/2007"
# } ,
# {
#     "name": "Caseres, Maria Antonia",
#     "section": "D",
#     "dob": "01/07/2006"
# } ,
# {
#     "name": "Castillo, Paulina Milagros",
#     "section": "D",
#     "dob": "01/06/2007"
# } ,
# {
#     "name": "Correa Segovia, Hugo Mariano",
#     "section": "D",
#     "dob": "04/12/2006"
# } ,
# {
#     "name": "Correa Segovia, Hugo Mariano",
#     "section": "D",
#     "dob": "04/12/2006"
# } ,
# {
#     "name": "D Elia, Alvaro Tadeo",
#     "section": "D",
#     "dob": "27/08/2006"
# } ,
# {
#     "name": "Flores, Victoria Agustina",
#     "section": "D",
#     "dob": "12/12/2006"
# } ,
# {
#     "name": "Geronimo Soriano, Lizzie Amaya",
#     "section": "D",
#     "dob": "20/01/2007"
# } ,
# {
#     "name": "Guzman, Angélica Morena",
#     "section": "D",
#     "dob": "11/04/2007"
# } ,
# {
#     "name": "Guzman, Jazmin Esmeralda Belen",
#     "section": "D",
#     "dob": "31/07/2006"
# } ,
# {
#     "name": "Jaime, Anita Maria Belen",
#     "section": "D",
#     "dob": "19/04/2007"
# } ,
# {
#     "name": "Lacour Polo, Nazarena",
#     "section": "D",
#     "dob": "19/12/2005"
# } ,
# {
#     "name": "Lascano Guanca, Marcelo Fabricio",
#     "section": "D",
#     "dob": "17/02/2006"
# } ,
# {
#     "name": "Lezcano, Celia Morena",
#     "section": "D",
#     "dob": "01/07/2005"
# } ,
# {
#     "name": "Martinez, Tomas Andres",
#     "section": "D",
#     "dob": "22/03/2007"
# } ,
# {
#     "name": "Portella Valdivia, Pedro Francisco",
#     "section": "D",
#     "dob": "24/01/2007"
# } ,
# {
#     "name": "Retamal Cisneros, Zacarias Josue",
#     "section": "D",
#     "dob": "24/02/2007"
# } ,
# {
#     "name": "Rosales, Francisco Gabriel",
#     "section": "D",
#     "dob": "14/11/2006"
# } ,
# {
#     "name": "Salem Barba, Mahia",
#     "section": "D",
#     "dob": "14/10/2005"
# } ,
# {
#     "name": "Soto Camara, Agustin Ignacio",
#     "section": "D",
#     "dob": "07/11/2005"
# } ,
# {
#     "name": "Villalba, Irina",
#     "section": "D",
#     "dob": "09/09/2006"
# } ,
# {
#     "name": "Voltolini, Emanuel Tobias",
#     "section": "D",
#     "dob": "17/09/2006"
# } ,
# {
#     "name": "Zalazar, Santino Stefano",
#     "section": "D",
#     "dob": "30/09/2006"
# } ,
# {
#     "name": "Zalazar, Santino Stefano",
#     "section": "D",
#     "dob": "30/09/2006"
# } ,

# %% [markdown]
# ## Dada la lista estudiantes:
# > - Hacer una celda para resolver cada punto.
# - El TP resuelto será revisado en tu repositorio, no es necesario que lo envíes, pero sí que lo pushees correctamente.
# - En la nota inicial se contempla:
#   - La incorporación de este documento a tu propio respositorio.
#   - El pusheo de los cambios realizados.
#   - La resolución de los ejercicios propuestos.

# %% [markdown]
# 1. Dada la lista de estudiantes, elimina los elementos repetidos de la misma, usando para ello una estructura set. El resultado final debe ser una lista, con la misma estructura de la original, pero sin datos repetidos.
#
# Para esto tener en cuenta que:
# - Los conjuntos solo pueden almacenar datos inmutables.
# - Los diccionarios son estructuras mutables.
# - dict.items() devuelve una lista de tuplas.
# - dict(tupla) genera un diccionario, donde el primer elemento de la tupla es la clave, y el segundo el valor. Ej:
#   -
#   ```python
#   dict([("Alberto", 10), ("José", 7), ("Dario", 14), ("Ana", 8), ("Maria", 9), ("Emilia", 10)])
#
#   va a generar el siguiente diccionario:
#
#   ```python
#   {'Alberto': 10, 'José': 7, 'Dario': 14, 'Ana': 8, 'Maria': 9, 'Emilia': 10}
#   ```

# %%
lista_tuplas  = []
estudiantes_sin_repetidos  = []
for estudiante in estudiantes:
  tupla = tuple(estudiante.items())
  lista_tuplas.append(tupla)
print(lista_tuplas)
conj_tuplas = set(lista_tuplas)
print(conj_tuplas)
for  estudiante in conj_tuplas:
  un_estudiante = dict(estudiante)
  estudiantes_sin_repetidos.append(un_estudiante)
for estudiante in estudiantes_sin_repetidos:
  print(estudiante)
# Out:
# [(('name', 'Abud Laspiur, Lourdes Mariel'), ('section', 'C'), ('dob', '05/12/2006')), (('name', 'Amador, Luana Micaela'), ('section', 'C'), ('dob', '09/12/2006')), (('name', 'Anaquin, Leonardo Ezequiel'), ('section', 'C'), ('dob', '06/09/2005')), (('name', 'Araoz Sanchez, Lautaro Nahuel'), ('section', 'C'), ('dob', '28/12/2005')), (('name', 'Argañaraz, Agostina Abril'), ('section', 'C'), ('dob', '11/10/2006')), (('name', 'Barrera, Matias Ezequiel'), ('section', 'C'), ('dob', '27/02/2007')), (('name', 'Barrera, Matias Ezequiel'), ('section', 'C'), ('dob', '27/02/2007')), (('name', 'Barrozo Vedia, Joaquin Nicolas'), ('section', 'C'), ('dob', '15/04/2006')), (('name', 'Bettinelli, Valentino'), ('section', 'C'), ('dob', '12/07/2006')), (('name', 'Bracamonte Martinez, Salvador'), ('section', 'C'), ('dob', '02/11/2005')), (('name', 'Colque Rivero, Ariana Zoe Del Valle'), ('section', 'C'), ('dob', '27/12/2006')), (('name', 'Diaz, Dulce Maitena'), ('section', 'C'), ('dob', '11/12/2006')), (('name', 'Figueroa, Santino Josue'), ('section', 'C'), ('dob', '12/05/2007')), (('name', 'Figueroa, Santino Josue'), ('section', 'C'), ('dob', '12/05/2007')), (('name', 'Flores Cardozo, Agustina Tiara'), ('section', 'C'), ('dob', '18/03/2006')), (('name', 'Gallo, Octavio Ismael'), ('section', 'C'), ('dob', '04/08/2006')), (('name', 'Galvan, Lourdes Yamila'), ('section', 'C'), ('dob', '19/08/2005')), (('name', 'Giangreco, Vitto Tomasso'), ('section', 'C'), ('dob', '21/03/2007')), (('name', 'Grancara, Martina Luna'), ('section', 'C'), ('dob', '15/12/2006')), (('name', 'Guanca, Sara Elizabeth'), ('section', 'C'), ('dob', '17/01/2007')), (('name', 'Lopez, Victoria Constanza'), ('section', 'C'), ('dob', '12/11/2007')), (('name', 'Mamani Garrido, Rosario Agostina'), ('section', 'C'), ('dob', '24/10/2006')), (('name', 'Marinaro, Martin Ezequiel'), ('section', 'C'), ('dob', '03/11/2006')), (('name', 'Merluzzi Dagum, Ignacio'), ('section', 'C'), ('dob', '22/12/2005')), (('name', 'Messina, Martina'), ('section', 'C'), ('dob', '13/07/2005')), (('name', 'Rasuk, Karim'), ('section', 'C'), ('dob', '13/07/2007')), (('name', 'Rasuk, Karim'), ('section', 'C'), ('dob', '13/07/2007')), (('name', 'Rios, Lucia Magali'), ('section', 'C'), ('dob', '22/09/2006')), (('name', 'Sanchez Flores, Matías Agustín'), ('section', 'C'), ('dob', '15/02/2007')), (('name', 'Scarano, Renato Marcelo'), ('section', 'C'), ('dob', '06/12/2006')), (('name', 'Sierra, Lucas Mauricio'), ('section', 'C'), ('dob', '03/04/2005')), (('name', 'Tapia, Martin Gabriel'), ('section', 'C'), ('dob', '30/05/2006')), (('name', 'Vilte, Mia Antonella Alondra'), ('section', 'C'), ('dob', '10/09/2005')), (('name', 'Virgillito, Katya Milena'), ('section', 'C'), ('dob', '19/06/2007')), (('name', 'Alurralde, Solange Stefania'), ('section', 'D'), ('dob', '02/04/2007')), (('name', 'Alvarado, Ludmila Del Milagro'), ('section', 'D'), ('dob', '06/09/2006')), (('name', 'Angel, Camila Juliana'), ('section', 'D'), ('dob', '07/03/2007')), (('name', 'Arenas, Lucas Gabriel'), ('section', 'D'), ('dob', '26/06/2007')), (('name', 'Caseres, Maria Antonia'), ('section', 'D'), ('dob', '01/07/2006')), (('name', 'Castillo, Paulina Milagros'), ('section', 'D'), ('dob', '01/06/2007')), (('name', 'Correa Segovia, Hugo Mariano'), ('section', 'D'), ('dob', '04/12/2006')), (('name', 'Correa Segovia, Hugo Mariano'), ('section', 'D'), ('dob', '04/12/2006')), (('name', 'D Elia, Alvaro Tadeo'), ('section', 'D'), ('dob', '27/08/2006')), (('name', 'Flores, Victoria Agustina'), ('section', 'D'), ('dob', '12/12/2006')), (('name', 'Geronimo Soriano, Lizzie Amaya'), ('section', 'D'), ('dob', '20/01/2007')), (('name', 'Guzman, Angélica Morena'), ('section', 'D'), ('dob', '11/04/2007')), (('name', 'Guzman, Jazmin Esmeralda Belen'), ('section', 'D'), ('dob', '31/07/2006')), (('name', 'Jaime, Anita Maria Belen'), ('section', 'D'), ('dob', '19/04/2007')), (('name', 'Lacour Polo, Nazarena'), ('section', 'D'), ('dob', '19/12/2005')), (('name', 'Lascano Gua ...
# {(('name', 'Salem Barba, Mahia'), ('section', 'D'), ('dob', '14/10/2005')), (('name', 'Martinez, Tomas Andres'), ('section', 'D'), ('dob', '22/03/2007')), (('name', 'Araoz Sanchez, Lautaro Nahuel'), ('section', 'C'), ('dob', '28/12/2005')), (('name', 'D Elia, Alvaro Tadeo'), ('section', 'D'), ('dob', '27/08/2006')), (('name', 'Giangreco, Vitto Tomasso'), ('section', 'C'), ('dob', '21/03/2007')), (('name', 'Vilte, Mia Antonella Alondra'), ('section', 'C'), ('dob', '10/09/2005')), (('name', 'Correa Segovia, Hugo Mariano'), ('section', 'D'), ('dob', '04/12/2006')), (('name', 'Guzman, Jazmin Esmeralda Belen'), ('section', 'D'), ('dob', '31/07/2006')), (('name', 'Barrera, Matias Ezequiel'), ('section', 'C'), ('dob', '27/02/2007')), (('name', 'Lezcano, Celia Morena'), ('section', 'D'), ('dob', '01/07/2005')), (('name', 'Virgillito, Katya Milena'), ('section', 'C'), ('dob', '19/06/2007')), (('name', 'Guzman, Angélica Morena'), ('section', 'D'), ('dob', '11/04/2007')), (('name', 'Scarano, Renato Marcelo'), ('section', 'C'), ('dob', '06/12/2006')), (('name', 'Abud Laspiur, Lourdes Mariel'), ('section', 'C'), ('dob', '05/12/2006')), (('name', 'Bracamonte Martinez, Salvador'), ('section', 'C'), ('dob', '02/11/2005')), (('name', 'Rasuk, Karim'), ('section', 'C'), ('dob', '13/07/2007')), (('name', 'Arenas, Lucas Gabriel'), ('section', 'D'), ('dob', '26/06/2007')), (('name', 'Castillo, Paulina Milagros'), ('section', 'D'), ('dob', '01/06/2007')), (('name', 'Guanca, Sara Elizabeth'), ('section', 'C'), ('dob', '17/01/2007')), (('name', 'Rios, Lucia Magali'), ('section', 'C'), ('dob', '22/09/2006')), (('name', 'Mamani Garrido, Rosario Agostina'), ('section', 'C'), ('dob', '24/10/2006')), (('name', 'Portella Valdivia, Pedro Francisco'), ('section', 'D'), ('dob', '24/01/2007')), (('name', 'Merluzzi Dagum, Ignacio'), ('section', 'C'), ('dob', '22/12/2005')), (('name', 'Caseres, Maria Antonia'), ('section', 'D'), ('dob', '01/07/2006')), (('name', 'Barrozo Vedia, Joaquin Nicolas'), ('section', 'C'), ('dob', '15/04/2006')), (('name', 'Flores Cardozo, Agustina Tiara'), ('section', 'C'), ('dob', '18/03/2006')), (('name', 'Colque Rivero, Ariana Zoe Del Valle'), ('section', 'C'), ('dob', '27/12/2006')), (('name', 'Tapia, Martin Gabriel'), ('section', 'C'), ('dob', '30/05/2006')), (('name', 'Figueroa, Santino Josue'), ('section', 'C'), ('dob', '12/05/2007')), (('name', 'Galvan, Lourdes Yamila'), ('section', 'C'), ('dob', '19/08/2005')), (('name', 'Rosales, Francisco Gabriel'), ('section', 'D'), ('dob', '14/11/2006')), (('name', 'Villalba, Irina'), ('section', 'D'), ('dob', '09/09/2006')), (('name', 'Angel, Camila Juliana'), ('section', 'D'), ('dob', '07/03/2007')), (('name', 'Diaz, Dulce Maitena'), ('section', 'C'), ('dob', '11/12/2006')), (('name', 'Geronimo Soriano, Lizzie Amaya'), ('section', 'D'), ('dob', '20/01/2007')), (('name', 'Soto Camara, Agustin Ignacio'), ('section', 'D'), ('dob', '07/11/2005')), (('name', 'Messina, Martina'), ('section', 'C'), ('dob', '13/07/2005')), (('name', 'Marinaro, Martin Ezequiel'), ('section', 'C'), ('dob', '03/11/2006')), (('name', 'Sanchez Flores, Matías Agustín'), ('section', 'C'), ('dob', '15/02/2007')), (('name', 'Jaime, Anita Maria Belen'), ('section', 'D'), ('dob', '19/04/2007')), (('name', 'Lascano Guanca, Marcelo Fabricio'), ('section', 'D'), ('dob', '17/02/2006')), (('name', 'Amador, Luana Micaela'), ('section', 'C'), ('dob', '09/12/2006')), (('name', 'Argañaraz, Agostina Abril'), ('section', 'C'), ('dob', '11/10/2006')), (('name', 'Gallo, Octavio Ismael'), ('section', 'C'), ('dob', '04/08/2006')), (('name', 'Flores, Victoria Agustina'), ('section', 'D'), ('dob', '12/12/2006')), (('name', 'Anaquin, Leonardo Ezequiel'), ('section', 'C'), ('dob', '06/09/2005')), (('name', 'Lopez, Victoria Constanza'), ('section', 'C'), ('dob', '12/11/2007')), (('name', 'Alvarado, Ludmila Del Milagro'), ('section', 'D'), ('dob', '06/09/2006')), (('name', 'Retamal Cisneros, Zacarias Josue'), ('section', 'D'), ('dob', '24/02/200 ...
# {'name': 'Salem Barba, Mahia', 'section': 'D', 'dob': '14/10/2005'}
# {'name': 'Martinez, Tomas Andres', 'section': 'D', 'dob': '22/03/2007'}
# {'name': 'Araoz Sanchez, Lautaro Nahuel', 'section': 'C', 'dob': '28/12/2005'}
# {'name': 'D Elia, Alvaro Tadeo', 'section': 'D', 'dob': '27/08/2006'}
# {'name': 'Giangreco, Vitto Tomasso', 'section': 'C', 'dob': '21/03/2007'}
# {'name': 'Vilte, Mia Antonella Alondra', 'section': 'C', 'dob': '10/09/2005'}
# {'name': 'Correa Segovia, Hugo Mariano', 'section': 'D', 'dob': '04/12/2006'}
# {'name': 'Guzman, Jazmin Esmeralda Belen', 'section': 'D', 'dob': '31/07/2006'}
# {'name': 'Barrera, Matias Ezequiel', 'section': 'C', 'dob': '27/02/2007'}
# {'name': 'Lezcano, Celia Morena', 'section': 'D', 'dob': '01/07/2005'}
# {'name': 'Virgillito, Katya Milena', 'section': 'C', 'dob': '19/06/2007'}
# {'name': 'Guzman, Angélica Morena', 'section': 'D', 'dob': '11/04/2007'}
# {'name': 'Scarano, Renato Marcelo', 'section': 'C', 'dob': '06/12/2006'}
# {'name': 'Abud Laspiur, Lourdes Mariel', 'section': 'C', 'dob': '05/12/2006'}
# {'name': 'Bracamonte Martinez, Salvador', 'section': 'C', 'dob': '02/11/2005'}
# {'name': 'Rasuk, Karim', 'section': 'C', 'dob': '13/07/2007'}
# {'name': 'Arenas, Lucas Gabriel', 'section': 'D', 'dob': '26/06/2007'}
# {'name': 'Castillo, Paulina Milagros', 'section': 'D', 'dob': '01/06/2007'}
# {'name': 'Guanca, Sara Elizabeth', 'section': 'C', 'dob': '17/01/2007'}
# {'name': 'Rios, Lucia Magali', 'section': 'C', 'dob': '22/09/2006'}
# {'name': 'Mamani Garrido, Rosario Agostina', 'section': 'C', 'dob': '24/10/2006'}
# {'name': 'Portella Valdivia, Pedro Francisco', 'section': 'D', 'dob': '24/01/2007'}
# {'name': 'Merluzzi Dagum, Ignacio', 'section': 'C', 'dob': '22/12/2005'}
# {'name': 'Caseres, Maria Antonia', 'section': 'D', 'dob': '01/07/2006'}
# {'name': 'Barrozo Vedia, Joaquin Nicolas', 'section': 'C', 'dob': '15/04/2006'}
# {'name': 'Flores Cardozo, Agustina Tiara', 'section': 'C', 'dob': '18/03/2006'}
# {'name': 'Colque Rivero, Ariana Zoe Del Valle', 'section': 'C', 'dob': '27/12/2006'}
# {'name': 'Tapia, Martin Gabriel', 'section': 'C', 'dob': '30/05/2006'}
# {'name': 'Figueroa, Santino Josue', 'section': 'C', 'dob': '12/05/2007'}
# {'name': 'Galvan, Lourdes Yamila', 'section': 'C', 'dob': '19/08/2005'}
# {'name': 'Rosales, Francisco Gabriel', 'section': 'D', 'dob': '14/11/2006'}
# {'name': 'Villalba, Irina', 'section': 'D', 'dob': '09/09/2006'}
# {'name': 'Angel, Camila Juliana', 'section': 'D', 'dob': '07/03/2007'}
# {'name': 'Diaz, Dulce Maitena', 'section': 'C', 'dob': '11/12/2006'}
# {'name': 'Geronimo Soriano, Lizzie Amaya', 'section': 'D', 'dob': '20/01/2007'}
# {'name': 'Soto Camara, Agustin Ignacio', 'section': 'D', 'dob': '07/11/2005'}
# {'name': 'Messina, Martina', 'section': 'C', 'dob': '13/07/2005'}
# {'name': 'Marinaro, Martin Ezequiel', 'section': 'C', 'dob': '03/11/2006'}
# {'name': 'Sanchez Flores, Matías Agustín', 'section': 'C', 'dob': '15/02/2007'}
# {'name': 'Jaime, Anita Maria Belen', 'section': 'D', 'dob': '19/04/2007'}
# {'name': 'Lascano Guanca, Marcelo Fabricio', 'section': 'D', 'dob': '17/02/2006'}
# {'name': 'Amador, Luana Micaela', 'section': 'C', 'dob': '09/12/2006'}
# {'name': 'Argañaraz, Agostina Abril', 'section': 'C', 'dob': '11/10/2006'}
# {'name': 'Gallo, Octavio Ismael', 'section': 'C', 'dob': '04/08/2006'}
# {'name': 'Flores, Victoria Agustina', 'section': 'D', 'dob': '12/12/2006'}
# {'name': 'Anaquin, Leonardo Ezequiel', 'section': 'C', 'dob': '06/09/2005'}
# {'name': 'Lopez, Victoria Constanza', 'section': 'C', 'dob': '12/11/2007'}
# {'name': 'Alvarado, Ludmila Del Milagro', 'section': 'D', 'dob': '06/09/2006'}
# {'name': 'Retamal Cisneros, Zacarias Josue', 'section': 'D', 'dob': '24/02/2007'}
# {'name': 'Zalazar, Santino Stefano', 'section': 'D', 'dob': '30/09/2006'}
# {'name': 'Grancara, Martina Luna', 'section': 'C', 'dob': '15/12/2006'}
# {'name': 'Voltolini, Emanuel Tobias', 'section': 'D', 'dob': '17/09/2006'}
# {'name': 'Bettinelli, Valentino', 'section': 'C', 'dob': '12/07/2006'}
# {'name': 'Sierra, Lucas Mauricio', 'section': 'C', 'dob': '03/04/2005'}
# {'name': 'Lacour Polo, Nazarena', 'section': 'D', 'dob': '19/12/2005'}
# {'name': 'Alurralde, Solange Stefania', 'section': 'D', 'dob': '02/04/2007'}

# %% [markdown]
# 2. Crea un conjunto de nombres y otro de apellidos para 5C y  para 5D.
# - Muestra los conjuntos generados
#
# > recordá que los conjuntos solo pueden almacenar datos inmutables

# %%
nombres_5c = set()
apellidos_5c= set()
nombres_5d= set()
apellidos_5d= set()
for estudiante in estudiantes:
  nombre_completo = estudiante["name"]
  apellido,nombre = nombre_completo.split(",")
  apellidos = apellido.split(" ")
  nombres = nombre.strip().split(" ")
  if estudiante["section"] == "C":
    for nombre in nombres:
      nombres_5c.add(apellido)
  else:
    for nombre in nombres:
      nombres_5d.add(nombre)
    for apellido in apellidos:
      apellidos_5d.add(apellido)
print(f"{nombres_5c= }")
print(f"{apellidos_5c= }")
print(f"{nombres_5d= }")
print(f"{apellidos_5d= }")
# Out:
# nombres_5c= {'Bettinelli', 'Diaz', 'Rasuk', 'Tapia', 'Mamani Garrido', 'Flores Cardozo', 'Marinaro', 'Sanchez Flores', 'Lopez', 'Vilte', 'Bracamonte Martinez', 'Scarano', 'Figueroa', 'Galvan', 'Amador', 'Abud Laspiur', 'Messina', 'Rios', 'Colque Rivero', 'Gallo', 'Guanca', 'Grancara', 'Giangreco', 'Merluzzi Dagum', 'Sierra', 'Anaquin', 'Barrozo Vedia', 'Argañaraz', 'Araoz Sanchez', 'Barrera', 'Virgillito'}
# apellidos_5c= set()
# nombres_5d= {'Celia', 'Hugo', 'Agustin', 'Amaya', 'Paulina', 'Andres', 'Milagro', 'Emanuel', 'Solange', 'Marcelo', 'Lizzie', 'Belen', 'Anita', 'Josue', 'Ludmila', 'Pedro', 'Antonia', 'Tadeo', 'Tobias', 'Esmeralda', 'Nazarena', 'Milagros', 'Stefania', 'Victoria', 'Irina', 'Lucas', 'Juliana', 'Maria', 'Zacarias', 'Del', 'Jazmin', 'Gabriel', 'Alvaro', 'Angélica', 'Camila', 'Agustina', 'Santino', 'Mariano', 'Mahia', 'Fabricio', 'Stefano', 'Tomas', 'Morena', 'Francisco', 'Ignacio'}
# apellidos_5d= {'Barba', 'Rosales', 'Arenas', 'Caseres', 'Jaime', 'Polo', 'Guzman', 'D', 'Soto', 'Martinez', 'Correa', 'Soriano', 'Lacour', 'Alurralde', 'Zalazar', 'Villalba', 'Retamal', 'Geronimo', 'Guanca', 'Camara', 'Elia', 'Castillo', 'Segovia', 'Voltolini', 'Lascano', 'Cisneros', 'Lezcano', 'Valdivia', 'Salem', 'Portella', 'Angel', 'Flores', 'Alvarado'}

# %% [markdown]
# 3. Muestra cuantos nombres únicos hay en cada curso.

# %%
lista_nombres = []
for estudiante in estudiantes:
    nombre_completo = estudiante["name"]
    apellido,nombre = nombre_completo.split(",")
    nombres_separados = nombre.split(" ")
    for nombre in nombres_separados:
        lista_nombres.append(nombre)
print(lista_nombres)
ocurrencias_nombres = {}
for nombre in lista_nombres:
    if nombre in ocurrencias_nombres:
        ocurrencias_nombres[nombre] += 1
    else:
        ocurrencias_nombres[nombre] = 1
for nombre, count in ocurrencias_nombres.items():
    if count == 1:
        print({nombre})
# Out:
# ['', 'Lourdes', 'Mariel', '', 'Luana', 'Micaela', '', 'Leonardo', 'Ezequiel', '', 'Lautaro', 'Nahuel', '', 'Agostina', 'Abril', '', 'Matias', 'Ezequiel', '', 'Matias', 'Ezequiel', '', 'Joaquin', 'Nicolas', '', 'Valentino', '', 'Salvador', '', 'Ariana', 'Zoe', 'Del', 'Valle', '', 'Dulce', 'Maitena', '', 'Santino', 'Josue', '', 'Santino', 'Josue', '', 'Agustina', 'Tiara', '', 'Octavio', 'Ismael', '', 'Lourdes', 'Yamila', '', 'Vitto', 'Tomasso', '', 'Martina', 'Luna', '', 'Sara', 'Elizabeth', '', 'Victoria', 'Constanza', '', 'Rosario', 'Agostina', '', 'Martin', 'Ezequiel', '', 'Ignacio', '', 'Martina', '', 'Karim', '', 'Karim', '', 'Lucia', 'Magali', '', 'Matías', 'Agustín', '', 'Renato', 'Marcelo', '', 'Lucas', 'Mauricio', '', 'Martin', 'Gabriel', '', 'Mia', 'Antonella', 'Alondra', '', 'Katya', 'Milena', '', 'Solange', 'Stefania', '', 'Ludmila', 'Del', 'Milagro', '', 'Camila', 'Juliana', '', 'Lucas', 'Gabriel', '', 'Maria', 'Antonia', '', 'Paulina', 'Milagros', '', 'Hugo', 'Mariano', '', 'Hugo', 'Mariano', '', 'Alvaro', 'Tadeo', '', 'Victoria', 'Agustina', '', 'Lizzie', 'Amaya', '', 'Angélica', 'Morena', '', 'Jazmin', 'Esmeralda', 'Belen', '', 'Anita', 'Maria', 'Belen', '', 'Nazarena', '', 'Marcelo', 'Fabricio', '', 'Celia', 'Morena', '', 'Tomas', 'Andres', '', 'Pedro', 'Francisco', '', 'Zacarias', 'Josue', '', 'Francisco', 'Gabriel', '', 'Mahia', '', 'Agustin', 'Ignacio', '', 'Irina', '', 'Emanuel', 'Tobias', '', 'Santino', 'Stefano', '', 'Santino', 'Stefano']
# {'Mariel'}
# {'Luana'}
# {'Micaela'}
# {'Leonardo'}
# {'Lautaro'}
# {'Nahuel'}
# {'Abril'}
# {'Joaquin'}
# {'Nicolas'}
# {'Valentino'}
# {'Salvador'}
# {'Ariana'}
# {'Zoe'}
# {'Valle'}
# {'Dulce'}
# {'Maitena'}
# {'Tiara'}
# {'Octavio'}
# {'Ismael'}
# {'Yamila'}
# {'Vitto'}
# {'Tomasso'}
# {'Luna'}
# {'Sara'}
# {'Elizabeth'}
# {'Constanza'}
# {'Rosario'}
# {'Lucia'}
# {'Magali'}
# {'Matías'}
# {'Agustín'}
# {'Renato'}
# {'Mauricio'}
# {'Mia'}
# {'Antonella'}
# {'Alondra'}
# {'Katya'}
# {'Milena'}
# {'Solange'}
# {'Stefania'}
# {'Ludmila'}
# {'Milagro'}
# {'Camila'}
# {'Juliana'}
# {'Antonia'}
# {'Paulina'}
# {'Milagros'}
# {'Alvaro'}
# {'Tadeo'}
# {'Lizzie'}
# {'Amaya'}
# {'Angélica'}
# {'Jazmin'}
# {'Esmeralda'}
# {'Anita'}
# {'Nazarena'}
# {'Fabricio'}
# {'Celia'}
# {'Tomas'}
# {'Andres'}
# {'Pedro'}
# {'Zacarias'}
# {'Mahia'}
# {'Agustin'}
# {'Irina'}
# {'Emanuel'}
# {'Tobias'}

# %% [markdown]
# 4. Muestra cuantos apellidos únicos hay en cada curso.

# %%
lista_nombres = []
for estudiante in estudiantes:
    nombres = estudiante["name"]
    nombres_separados = nombres.split(" ")
    for nombre in nombres_separados:
        nombre.strip()
        lista_nombres.append(nombre)
ocurrencias_nombres = {}
for nombre in lista_nombres:
    if nombre in ocurrencias_nombres:
        ocurrencias_nombres[nombre] += 1
    else:
        ocurrencias_nombres[nombre] = 1
for nombre, ocurrencia in ocurrencias_nombres.items():
    print(f"El nombre {nombre} aparece {ocurrencia} veces.")
# Out:
# El nombre Abud aparece 1 veces.
# El nombre Laspiur, aparece 1 veces.
# El nombre Lourdes aparece 2 veces.
# El nombre Mariel aparece 1 veces.
# El nombre Amador, aparece 1 veces.
# El nombre Luana aparece 1 veces.
# El nombre Micaela aparece 1 veces.
# El nombre Anaquin, aparece 1 veces.
# El nombre Leonardo aparece 1 veces.
# El nombre Ezequiel aparece 4 veces.
# El nombre Araoz aparece 1 veces.
# El nombre Sanchez, aparece 1 veces.
# El nombre Lautaro aparece 1 veces.
# El nombre Nahuel aparece 1 veces.
# El nombre Argañaraz, aparece 1 veces.
# El nombre Agostina aparece 2 veces.
# El nombre Abril aparece 1 veces.
# El nombre Barrera, aparece 2 veces.
# El nombre Matias aparece 2 veces.
# El nombre Barrozo aparece 1 veces.
# El nombre Vedia, aparece 1 veces.
# El nombre Joaquin aparece 1 veces.
# El nombre Nicolas aparece 1 veces.
# El nombre Bettinelli, aparece 1 veces.
# El nombre Valentino aparece 1 veces.
# El nombre Bracamonte aparece 1 veces.
# El nombre Martinez, aparece 2 veces.
# El nombre Salvador aparece 1 veces.
# El nombre Colque aparece 1 veces.
# El nombre Rivero, aparece 1 veces.
# El nombre Ariana aparece 1 veces.
# El nombre Zoe aparece 1 veces.
# El nombre Del aparece 2 veces.
# El nombre Valle aparece 1 veces.
# El nombre Diaz, aparece 1 veces.
# El nombre Dulce aparece 1 veces.
# El nombre Maitena aparece 1 veces.
# El nombre Figueroa, aparece 2 veces.
# El nombre Santino aparece 4 veces.
# El nombre Josue aparece 3 veces.
# El nombre Flores aparece 1 veces.
# El nombre Cardozo, aparece 1 veces.
# El nombre Agustina aparece 2 veces.
# El nombre Tiara aparece 1 veces.
# El nombre Gallo, aparece 1 veces.
# El nombre Octavio aparece 1 veces.
# El nombre Ismael aparece 1 veces.
# El nombre Galvan, aparece 1 veces.
# El nombre Yamila aparece 1 veces.
# El nombre Giangreco, aparece 1 veces.
# El nombre Vitto aparece 1 veces.
# El nombre Tomasso aparece 1 veces.
# El nombre Grancara, aparece 1 veces.
# El nombre Martina aparece 2 veces.
# El nombre Luna aparece 1 veces.
# El nombre Guanca, aparece 2 veces.
# El nombre Sara aparece 1 veces.
# El nombre Elizabeth aparece 1 veces.
# El nombre Lopez, aparece 1 veces.
# El nombre Victoria aparece 2 veces.
# El nombre Constanza aparece 1 veces.
# El nombre Mamani aparece 1 veces.
# El nombre Garrido, aparece 1 veces.
# El nombre Rosario aparece 1 veces.
# El nombre Marinaro, aparece 1 veces.
# El nombre Martin aparece 2 veces.
# El nombre Merluzzi aparece 1 veces.
# El nombre Dagum, aparece 1 veces.
# El nombre Ignacio aparece 2 veces.
# El nombre Messina, aparece 1 veces.
# El nombre Rasuk, aparece 2 veces.
# El nombre Karim aparece 2 veces.
# El nombre Rios, aparece 1 veces.
# El nombre Lucia aparece 1 veces.
# El nombre Magali aparece 1 veces.
# El nombre Sanchez aparece 1 veces.
# El nombre Flores, aparece 2 veces.
# El nombre Matías aparece 1 veces.
# El nombre Agustín aparece 1 veces.
# El nombre Scarano, aparece 1 veces.
# El nombre Renato aparece 1 veces.
# El nombre Marcelo aparece 2 veces.
# El nombre Sierra, aparece 1 veces.
# El nombre Lucas aparece 2 veces.
# El nombre Mauricio aparece 1 veces.
# El nombre Tapia, aparece 1 veces.
# El nombre Gabriel aparece 3 veces.
# El nombre Vilte, aparece 1 veces.
# El nombre Mia aparece 1 veces.
# El nombre Antonella aparece 1 veces.
# El nombre Alondra aparece 1 veces.
# El nombre Virgillito, aparece 1 veces.
# El nombre Katya aparece 1 veces.
# El nombre Milena aparece 1 veces.
# El nombre Alurralde, aparece 1 veces.
# El nombre Solange aparece 1 veces.
# El nombre Stefania aparece 1 veces.
# El nombre Alvarado, aparece 1 veces.
# El nombre Ludmila aparece 1 veces.
# El nombre Milagro aparece 1 veces.
# El nombre Angel, aparece 1 veces.
# El nombre Camila aparece 1 veces.
# El nombre Juliana aparece 1 veces.
# El nombre Arenas, aparece 1 veces.
# El nombre Caseres, aparece 1 veces.
# El nombre Maria aparece 2 veces.
# El nombre Antonia aparece 1 veces.
# El nombre Castillo, aparece 1 veces.
# El nombre Paulina aparece 1 veces.
# El nombre Milagros aparece 1 veces.
# El nombre Correa aparece 2 veces.
# El nombre Segovia, aparece 2 veces.
# El nombre Hugo aparece 2 veces.
# El nombre Mariano aparece 2 veces.
# El nombre D aparece 1 veces.
# El nombre Elia, aparece 1 veces.
# El nombre Alvaro aparece 1 veces.
# El nombre Tadeo aparece 1 veces.
# El nombre Geronimo aparece 1 veces.
# El nombre Soriano, aparece 1 veces.
# El nombre Lizzie aparece 1 veces.
# El nombre Amaya aparece 1 veces.
# El nombre Guzman, aparece 2 veces.
# El nombre Angélica aparece 1 veces.
# El nombre Morena aparece 2 veces.
# El nombre Jazmin aparece 1 veces.
# El nombre Esmeralda aparece 1 veces.
# El nombre Belen aparece 2 veces.
# El nombre Jaime, aparece 1 veces.
# El nombre Anita aparece 1 veces.
# El nombre Lacour aparece 1 veces.
# El nombre Polo, aparece 1 veces.
# El nombre Nazarena aparece 1 veces.
# El nombre Lascano aparece 1 veces.
# El nombre Fabricio aparece 1 veces.
# El nombre Lezcano, aparece 1 veces.
# El nombre Celia aparece 1 veces.
# El nombre Tomas aparece 1 veces.
# El nombre Andres aparece 1 veces.
# El nombre Portella aparece 1 veces.
# El nombre Valdivia, aparece 1 veces.
# El nombre Pedro aparece 1 veces.
# El nombre Francisco aparece 2 veces.
# El nombre Retamal aparece 1 veces.
# El nombre Cisneros, aparece 1 veces.
# El nombre Zacarias aparece 1 veces.
# El nombre Rosales, aparece 1 veces.
# El nombre Salem aparece 1 veces.
# El nombre Barba, aparece 1 veces.
# El nombre Mahia aparece 1 veces.
# El nombre Soto aparece 1 veces.
# El nombre Camara, aparece 1 veces.
# El nombre Agustin aparece 1 veces.
# El nombre Villalba, aparece 1 veces.
# El nombre Irina aparece 1 veces.
# El nombre Voltolini, aparece 1 veces.
# El nombre Emanuel aparece 1 veces.
# El nombre Tobias aparece 1 veces.
# El nombre Zalazar, aparece 2 veces.
# El nombre Stefano aparece 2 veces.

# %% [markdown]
# 5. Mostrá los nombres que se aparecen em ambos cursos

# %%
pass

# %% [markdown]
# 6. Mostrá los apellidos que se aparecen en ambos cursos

# %%
pass

# %% [markdown]
# 7. Mostrá los nombres de los estudiantes de 5C que no existen en 5D y viceversa.

# %%
pass

# %% [markdown]
# 8. Mostrá los apellidos de los estudiantes de 5C que no existen en 5D y viceversa.

# %%
pass

# %% [markdown]
# 9. Mostrá todos los nombres, menos aquellos que existen en ambos cursos.

# %%
pass

# %% [markdown]
# 10. elimina tu nombre del conjunto al que pertenece

# %%
pass

# %% [markdown]
# 11. Solicita al usuario un nombre y un apellido y agregalos a los correspondientes conjuntos de tu curso.

# %%
pass

# %% [markdown]
# 12. Solicita un nombre y verifica si este existe en el diccionario
